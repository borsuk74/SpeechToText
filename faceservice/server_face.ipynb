# %%
from __future__ import division

import re
import sys
import grpc
import face_pb2
import face_pb2_grpc
from concurrent import futures
import random
import time
from PIL import Image

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class FaceServicer(face_pb2_grpc.FaceServiceServicer):
    '''Example of server to process faces. It takes 120-130ms to copy image
       from request, or around 8fps.'''
    def RecognizeFace(self, request, context):
        print("We got request!")
        
        timeStamp = request.timeStamp
        print(timeStamp)
        if len(request.videoContent) > 0:
           
            images = list(request.videoContent)
            image = Image.frombytes('RGBA', (160, 160), images[0])
            print("We got some image here!")
           
            plt.title(str(timeStamp))
            plt.imshow(image)
            plt.show()
            plt.clf()
            image.close()
            

        response = face_pb2.FaceRecognitionResponse(num=1)
        
        return response

# %%
def serve():    
    server = grpc.server(futures.ThreadPoolExecutor(max_workers=10))
    face_pb2_grpc.add_FaceServiceServicer_to_server(FaceServicer(), server)
    server.add_insecure_port('[::]:50052')
    server.start()
    server.wait_for_termination()

# %%
serve()
# Out:
# We got request!
# 23442365
# We got request!
# 23442979
# We got request!
# 23443107
# We got request!
# 23443297
# We got request!
# 23443496
# We got request!
# 23443715
# We got request!
# 23443902
# We got request!
# 23444074
# We got request!
# 23444263
# We got request!
# 23444388
# We got request!
# 23444554
# We got request!
# 23444700
# We got request!
# 23444900
# We got request!
# 23445113
# We got request!
# 23445253
# We got request!
# 23445395
# We got request!
# 23445545
# We got some image here!
# We got request!
# 23445966
# We got request!
# 23446157
# We got request!
# 23446329
# We got request!
# 23446482
# We got request!
# 23446608
# We got request!
# 23446813
# We got request!
# 23446921
# We got request!
# 23447014
# We got request!
# 23447111
# We got request!
# 23447211
# We got request!
# 23447323
# We got request!
# 23447419
# We got request!
# 23447541
# We got request!
# 23447635
# We got request!
# 23447734
# We got request!
# 23447836
# We got some image here!
# We got request!
# 23448186
# We got some image here!
# We got request!
# 23448575
# We got some image here!
# We got request!
# 23449036
# We got some image here!
# We got request!
# 23449387
# We got some image here!
# We got request!
# 23449746
# We got some image here!
# We got request!
# 23450122
# We got some image here!
# We got request!
# 23450494
# We got some image here!
# We got request!
# 23450942
# We got some image here!
# We got request!
# 23451359
# We got some image here!
# We got request!
# 23451736
# We got some image here!
# We got request!
# 23452174
# We got some image here!
# We got request!
# 23452583
# We got some image here!
# We got request!
# 23452930
# We got some image here!
# We got request!
# 23453324
# We got some image here!
# We got request!
# 23453685
# We got some image here!
# We got request!
# 23454060
# We got some image here!
# We got request!
# 23454418
# We got some image here!
# We got request!
# 23454765
# We got some image here!
# We got request!
# 23455210
# We got some image here!
# We got request!
# 23455565
# We got some image here!
# We got request!
# 23455978
# We got some image here!
# We got request!
# 23456330
# We got some image here!
# We got request!
# 23456702
# We got some image here!
# We got request!
# 23457049
# We got some image here!
# We got request!
# 23457434
# We got some image here!
# We got request!
# 23457823
# We got some image here!
# We got request!
# 23458170
# We got some image here!
# We got request!
# 23458520
# We got some image here!
# We got request!
# 23459111
# We got some image here!
# We got request!
# 23459441
# We got some image here!
# We got request!
# 23459795
# We got some image here!
# We got request!
# 23460167
# We got some image here!
# We got request!
# 23460559
# We got some image here!
# We got request!
# 23460924
# We got some image here!
# We got request!
# 23461384
# We got some image here!
# We got request!
# 23461765
# We got some image here!
# We got request!
# 23462134
# We got some image here!
# We got request!
# 23462511
# We got some image here!
# We got request!
# 23462862
# We got some image here!
# We got request!
# 23463406
# We got some image here!
# We got request!
# 23463793
# We got some image here!
# We got request!
# 23464128
# We got some image here!
# We got request!
# 23464464
# We got some image here!
# We got request!
# 23464835
# We got some image here!
# We got request!
# 23465199
# We got some image here!
# We got request!
# 23465531
# We got request!
# 23465616
# We got request!
# 23465713
# We got request!
# 23465809
# We got request!
# 23465911
# We got request!
# 23466001
# We got request!
# 23466168
# We got request!
# 23466266
# We got request!
# 23466363
# We got request!
# 23466446
# We got request!
# 23466537
# We got request!
# 23466627
# We got request!
# 23466722
# We got request!
# 23466811
# We got request!
# 23466914
# We got request!
# 23467010
# We got request!
# 23467300
# We got request!
# 23467409
# We got request!
# 23467500
# We got request!
# 23467604
# We got request!
# 23467696
# We got request!
# 23467783
# We got request!
# 23467872
# We got request!
# 23467959
# We got request!
# 23468048
# We got request!
# 23468140
# We got request!
# 23468228
# We got request!
# 23468327
# We got request!
# 23468411
# We got request!
# 23468494
# We got request!
# 23468625
# We got request!
# 23468728
# We got request!
# 23468813
# We got request!
# 23468914
# We got request!
# 23468997
# We got request!
# 23469086
# We got request!
# 23469167
# We got request!
# 23469261
# We got request!
# 23469349
# We got request!
# 23469434
# We got request!
# 23469519
# We got request!
# 23469610
# We got request!
# 23469700
# We got request!
# 23469801
# We got request!
# 23469891
# We got request!
# 23469971
# We got request!
# 23470053
# We got request!
# 23470150
# We got request!
# 23470240
# We got request!
# 23470330
# We got request!
# 23470416
# We got request!
# 23470501
# We got request!
# 23470584
# We got request!
# 23470667
# We got request!
# 23470750
# We got request!
# 23470834
# We got request!
# 23470917
# We got request!
# 23471002
# We got request!
# 23471089
# We got request!
# 23471390
# We got request!
# 23471480
# We got request!
# 23471564
# We got request!
# 23471653
# We got request!
# 23471738
# We got request!
# 23471821
# We got request!
# 23471904
# We got request!
# 23471988
# We got request!
# 23472071
# We got request!
# 23472149
# We got request!
# 23472229
# We got request!
# 23472336
# We got request!
# 23472420
# We got request!
# 23472504
# We got request!
# 23472592
# We got request!
# 23472676
# We got request!
# 23472771
# We got request!
# 23472856
# We got request!
# 23472939
# We got request!
# 23473013
# We got request!
# 23473094
# We got request!
# 23473176
# We got request!
# 23473270
# We got request!
# 23473343
# We got request!
# 23473422
# We got request!
# 23473499
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4f36a5ad7367> in <module>
# ----> 1 serve()
#
# <ipython-input-7-71cda7e93f19> in serve()
#       4     server.add_insecure_port('[::]:50052')
#       5     server.start()
# ----> 6     server.wait_for_termination()
#
# ~/google_research/lib/python3.6/site-packages/grpc/_server.py in wait_for_termination(self, timeout)
#     974         return _common.wait(self._state.termination_event.wait,
#     975                             self._state.termination_event.is_set,
# --> 976                             timeout=timeout)
#     977
#     978     def stop(self, grace):
#
# ~/google_research/lib/python3.6/site-packages/grpc/_common.py in wait(wait_fn, wait_complete_fn, timeout, spin_cb)
#     136     if timeout is None:
#     137         while not wait_complete_fn():
# --> 138             _wait_once(wait_fn, MAXIMUM_WAIT_TIMEOUT, spin_cb)
#     139     else:
#     140         end = time.time() + timeout
#
# ~/google_research/lib/python3.6/site-packages/grpc/_common.py in _wait_once(wait_fn, timeout, spin_cb)
#     101
#     102 def _wait_once(wait_fn, timeout, spin_cb):
# --> 103     wait_fn(timeout=timeout)
#     104     if spin_cb is not None:
#     105         spin_cb()
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# We got request!
# 23473586
